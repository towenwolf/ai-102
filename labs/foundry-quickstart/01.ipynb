# %%
from dotenv import load_dotenv
import os

load_dotenv()

endpoint = os.getenv("AZURE_AI_SERVICES_ENDPOINT")
key = os.getenv("AZURE_AI_SERVICES_KEY")

# %%
import os
from dotenv import load_dotenv
from azure.identity import DefaultAzureCredential
from azure.ai.projects import AIProjectClient

load_dotenv()

print(f"Using AZURE_AI_FOUNDRY_PROJECT_ENDPOINT: {os.environ['AZURE_AI_SERVICES_ENDPOINT']}")
print(f"Using AZURE_AI_FOUNDRY_MODEL_DEPLOYMENT_NAME: {os.environ['AZURE_AI_FOUNDRY_MODEL_DEPLOYMENT_NAME']}")

project_client = AIProjectClient(
    endpoint=os.environ["AZURE_AI_FOUNDRY_PROJECT_ENDPOINT"],
    credential=DefaultAzureCredential(),
)

openai_client = project_client.get_openai_client()

response = openai_client.responses.create(
    model=os.environ["AZURE_AI_FOUNDRY_MODEL_DEPLOYMENT_NAME"],
    input="What is the size of France in square miles?",
)
print(f"Response output: {response.output_text}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 8
#       4 from azure.ai.projects import AIProjectClient
#       6 load_dotenv()
# ----> 8 print(f"Using AZURE_AI_FOUNDRY_PROJECT_ENDPOINT: {os.environ['AZURE_AI_FOUNDRY_PROJECT_ENDPOINT']}")
#       9 print(f"Using AZURE_AI_FOUNDRY_MODEL_DEPLOYMENT_NAME: {os.environ['AZURE_AI_FOUNDRY_MODEL_DEPLOYMENT_NAME']}")
#      11 project_client = AIProjectClient(
#      12     endpoint=os.environ["AZURE_AI_FOUNDRY_PROJECT_ENDPOINT"],
#      13     credential=DefaultAzureCredential(),
#      14 )
#
# File <frozen os>:679, in __getitem__(self, key)
#
# KeyError: 'AZURE_AI_FOUNDRY_PROJECT_ENDPOINT'
